# %%
# !scrapy crawl ProductSpider
# Out:
# 2023-06-12 22:16:20 [scrapy.utils.log] INFO: Scrapy 2.9.0 started (bot: url_crawling)
# 2023-06-12 22:16:20 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.1, Twisted 22.10.0, Python 3.10.8 | packaged by conda-forge | (main, Nov 24 2022, 14:07:00) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 22.0.0 (OpenSSL 1.1.1s  1 Nov 2022), cryptography 38.0.1, Platform Windows-10-10.0.19045-SP0
# 2023-06-12 22:16:20 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'url_crawling',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'url_crawling.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['url_crawling.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-06-12 22:16:20 [asyncio] DEBUG: Using selector: SelectSelector
# 2023-06-12 22:16:20 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# ...
